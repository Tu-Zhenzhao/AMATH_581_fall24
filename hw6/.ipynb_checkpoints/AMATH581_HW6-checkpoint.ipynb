# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.fftpack import fft2, ifft2
import scipy.sparse as sparse
import matplotlib.pyplot as plt

# %%
# Define spectral k values
Lx, Ly = 20, 20
nx, ny = 64, 64
N = nx*ny

beta = 1.0
D1 = 0.1
D2 = 0.1 
m = 1  # number of spirals

# Define spatial domain and initial conditions
x2 = np.linspace(-Lx/2, Lx/2, nx + 1)
x = x2[:nx]
y2 = np.linspace(-Ly/2, Ly/2, ny + 1)
y = y2[:ny]

# Domain setup
#x = np.linspace(-10, 10, nx+1)
#y = np.linspace(-10, 10, ny+1)

# Initial conditions
X, Y = np.meshgrid(x, y)

r = np.sqrt(X**2 + Y**2)
theta = np.angle(X + 1j*Y)

u0 = np.tanh(r) * np.cos(m*theta - r)
v0 = np.tanh(r) * np.sin(m*theta - r)

u1 = fft2(u0).flatten()
v1 = fft2(v0).flatten()
y0 = np.concatenate([u1, v1])

# Time span
tspan = np.arange(0, 4 + 0.5, 0.5)

# Define spectral k values
kx = (2 * np.pi / Lx) * np.concatenate((np.arange(0, nx/2), np.arange(-nx/2, 0)))
kx[0] = 1e-6
ky = (2 * np.pi / Ly) * np.concatenate((np.arange(0, ny/2), np.arange(-ny/2, 0)))
ky[0] = 1e-6
KX, KY = np.meshgrid(kx, ky)
K = KX**2 + KY**2


def diffusion_rhs(t,y,beta, D1, D2, nx, ny, N, KX, KY):

    u1 = y[:N]
    v1 = y[N:2*N]

    # Reshape input
    u1_reshape = u1.reshape(nx,ny)
    v1_reshape = v1.reshape(nx,ny)
    u = ifft2(u1_reshape)
    v = ifft2(v1_reshape)

    # Compute Laplacians
    Lapu = -(KX**2)*u1_reshape-(KY**2)*u1_reshape
    Lapv = -(KX**2)*v1_reshape-(KY**2)*v1_reshape
    
    # Defining A
    A = u**2 + v**2
    A2 = A **2

    # Compute derivatives
    #ut = (fft2(1-A*u)-fft2(-beta*A*v)+D1*Lapu).flatten()
    #vt = (fft2(-beta*A*u)-fft2(1-A*v)+D2*Lapv).flatten()

    ut = (fft2((1-A2)*u-beta*A2*v)+D1*Lapu).flatten()
    vt = (fft2(beta*A2*u+(1-A2)*v)+D2*Lapv).flatten()
    
    return np.concatenate([ut, vt])

# Solve ODE
params = (beta, D1, D2, nx, ny, N, KX, KY)
sol = solve_ivp(diffusion_rhs,t_span=[0, 4],y0=y0,t_eval=tspan,method='RK45',args=params)

# Compute A1 (final solution in Fourier domain)
A1 = sol.y

A1plot = np.abs(ifft2(A1[:N,0].reshape(nx,ny)))
plt.pcolor(x,y, A1plot)

print(A1.shape)
print(A1)
# Out:
# (8192, 9)
# [[ 2.49400385e+01+0.00000000e+00j  3.34995821e+01-6.78096473e-15j
#    4.75121408e+01-9.80035237e-15j ... -8.37244565e+00-2.27744026e-15j
#   -7.56843804e+01+3.37898731e-14j -1.34597178e+02+6.65561316e-14j]
#  [-1.85566636e+01-5.81663109e+01j  1.45657179e-01-5.66998604e+01j
#    2.00645754e+01-5.24138699e+01j ...  9.32524272e+01+4.39533459e+00j
#    6.16702675e+01+5.62296815e+01j  5.95838958e+00+1.10096824e+02j]
#  [-1.60475587e+01+3.28279829e+01j -9.19219096e+00+1.19202814e+02j
#    4.41465571e+00+1.83780254e+02j ...  7.57156289e+01-1.07666407e+01j
#    3.27414650e+01-1.34137678e+02j -3.31586576e+01-2.32539284e+02j]
#  ...
#  [ 2.47302147e+01-5.66774723e+02j  1.14455585e+01-6.56700658e+02j
#   -9.48041503e-02-6.04515141e+02j ... -5.93769514e+01+3.66813406e+02j
#   -7.00854016e+01+5.24362072e+02j -6.60634933e+01+5.72472405e+02j]
#  [ 2.53372012e+01-3.61633792e+02j  6.02446597e+00-1.76457607e+02j
#   -1.16465708e+01+3.64913849e+01j ... -2.46808504e+01+4.50236720e+02j
#   -1.37584912e+01+3.14302977e+02j -4.31565341e+00+1.08054631e+02j]
#  [-6.47535010e+00+3.96245454e+01j -2.20924204e+01+1.03488028e+02j
#   -3.20292175e+01+1.50436894e+02j ... -4.14093385e+01+1.40374057e+02j
#   -2.97304196e+01+3.55878201e+01j -6.89152761e+00-9.75823129e+01j]]

# %%
# Define spectral k values
Lx, Ly = 20, 20
#nx, ny = 30, 30
nx, ny = 31, 31
N = nx*ny

beta = 1.0
D1 = 0.1
D2 = 0.1
m = 1  # number of spirals

# Define spatial domain and initial conditions
x2 = np.linspace(-Lx/2, Lx/2, nx + 1)
x = x2[:nx]
y2 = np.linspace(-Ly/2, Ly/2, ny + 1)
y = y2[:ny]

# Domain setup
#x = np.linspace(-10, 10, nx+1)
#y = np.linspace(-10, 10, ny+1)

# Initial conditions
X, Y = np.meshgrid(x, y)

r = np.sqrt(X**2 + Y**2)
theta = np.angle(X + 1j*Y)

u0 = np.tanh(r) * np.cos(m*theta - r)
v0 = np.tanh(r) * np.sin(m*theta - r)

u1 = fft2(u0).flatten()
v1 = fft2(v0).flatten()
y0 = np.concatenate([u1, v1])

# Time span
tspan = np.arange(0, 4 + 0.5, 0.5)

# Define spectral k values
kx = (2 * np.pi / Lx) * np.concatenate((np.arange(0, nx/2), np.arange(-nx/2, 0)))
kx[0] = 1e-6
ky = (2 * np.pi / Ly) * np.concatenate((np.arange(0, ny/2), np.arange(-ny/2, 0)))
ky[0] = 1e-6
KX, KY = np.meshgrid(kx, ky)
K = KX**2 + KY**2

def cheb(N):
    if N == 0:
        D = 0.
        x = 1.
    else:
        n = np.arange(0, N+1)
        x = np.cos(np.pi*n/N).reshape(N+1, 1)
        c = (np.hstack(([2.], np.ones(N-1), [2.])) * (-1)**n).reshape(N+1, 1)
        X = np.tile(x, (1, N+1))
        dX = X - X.T
        D = np.dot(c, 1./c.T) / (dX + np.eye(N+1))
        D -= np.diag(np.sum(D.T, axis=0))  # Changed sum() to np.sum()
    
    return D, x.reshape(N+1)

D, x = cheb(N)
D[N, :] = 0
D[0, :] = 0
D2 = np.dot(D, D)

x = 10*x

# Replace Kronecker product with sparse Kronecker sum
I = sparse.eye(N)
D2 = sparse.csr_matrix(np.dot(D, D))
L = sparse.kron(I, D2) + sparse.kron(D2, I)

#I = np.eye(len(D2))
#L = np.kron(I, D2) + np.kron(D2, I) # 2D Laplacian
#print(L.shape)


def diffusion_rhs(t,y,beta, D1, D2, nx, ny,N,L):

    u1 = y[:N]
    v1 = y[N:2*N]

    # Reshape input
    u1_re = u1.reshape(nx,ny)
    v1_re = v1.reshape(nx,ny)
    u = np.real(u1_re)
    v = np.real(v1_re)

    # Compute Laplacians
    Lapu = L*u
    Lapv = L*v

    # Defining A
    A = u**2 + v**2
    A2 = A **2

    # Compute derivatives
    #ut = (fft2(1-A*u)-fft2(-beta*A*v)+D1*Lapu).flatten()
    #vt = (fft2(-beta*A*u)-fft2(1-A*v)+D2*Lapv).flatten()

    ut = (fft2((1-A2)*u-beta*A2*v)+D1*Lapu).flatten()
    vt = (fft2(beta*A2*u+(1-A2)*v)+D2*Lapv).flatten()
    
    return np.concatenate([ut, vt])

# Solve ODE
params = (beta, D1, D2, nx, ny, N)
sol = solve_ivp(diffusion_rhs,t_span=[0, 4],y0=y0,t_eval=tspan,method='RK45',args=params)

# Compute A1 (final solution in Fourier domain)
A2 = sol.y
print(A2.shape)
print(A2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 71
#      69 I = sparse.eye(N)
#      70 D2 = sparse.csr_matrix(np.dot(D, D))
# ---> 71 L = sparse.kron(I, D2) + sparse.kron(D2, I)
#      73 #I = np.eye(len(D2))
#      74 #L = np.kron(I, D2) + np.kron(D2, I) # 2D Laplacian
#      75 #print(L.shape)
#      78 def diffusion_rhs(t,y,beta, D1, D2, nx, ny,N,L):
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_base.py:530, in _spbase.__add__(self, other)
#     528     if other.shape != self.shape:
#     529         raise ValueError("inconsistent shapes")
# --> 530     return self._add_sparse(other)
#     531 elif isdense(other):
#     532     other = np.broadcast_to(other, self.shape)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_compressed.py:357, in _cs_matrix._add_sparse(self, other)
#     356 def _add_sparse(self, other):
# --> 357     return self._binopt(other, '_plus_')
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_bsr.py:552, in _bsr_base._binopt(self, other, op, in_shape, out_shape)
#     548 """Apply the binary operation fn to two sparse matrices."""
#     550 # Ideally we'd take the GCDs of the blocksize dimensions
#     551 # and explode self and other to match.
# --> 552 other = self.__class__(other, blocksize=self.blocksize)
#     554 # e.g. bsr_plus_bsr, etc.
#     555 fn = getattr(_sparsetools, self.format + op + self.format)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_bsr.py:34, in _bsr_base.__init__(self, arg1, shape, dtype, copy, blocksize)
#      32         arg1 = arg1.copy()
#      33     else:
# ---> 34         arg1 = arg1.tobsr(blocksize=blocksize)
#      35     self.indptr, self.indices, self.data, self._shape = (
#      36         arg1.indptr, arg1.indices, arg1.data, arg1._shape
#      37     )
#      39 elif isinstance(arg1,tuple):
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_base.py:1045, in _spbase.tobsr(self, blocksize, copy)
#    1036 def tobsr(self, blocksize=None, copy=False):
#    1037     """Convert this array/matrix to Block Sparse Row format.
#    1038
#    1039     With copy=False, the data/indices may be shared between this array/matrix and
#    (...)
#    1043     the bsr_array/matrix.
#    1044     """
# -> 1045     return self.tocsr(copy=False).tobsr(blocksize=blocksize, copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_coo.py:344, in _coo_base.tocsr(self, copy)
#     342 else:
#     343     from ._csr import csr_array
# --> 344     indptr, indices, data, shape = self._coo_to_compressed(csr_array._swap)
#     346     x = self._csr_container((data, indices, indptr), shape=self.shape)
#     347     if not self.has_canonical_format:
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/sparse/_coo.py:366, in _coo_base._coo_to_compressed(self, swap)
#     363 indices = np.empty_like(minor, dtype=idx_dtype)
#     364 data = np.empty_like(self.data, dtype=self.dtype)
# --> 366 coo_tocsr(M, N, nnz, major, minor, self.data, indptr, indices, data)
#     367 return indptr, indices, data, self.shape
#
# KeyboardInterrupt:
